# %%
import requests,zipfile, io
from pathlib import Path
from os import walk
import glob2

# %%
cookies = {"gclubsess":"4df45542b47d394aad4caf33b5111c7d8cefbb2f"}
player_list=[767208,767166,765902,866021,1284651,759993,109631,47742,273342,593990]
year=2021
month=3
dest_folder = "/home/marcel/projetos/data/csgo_analyze/replays/mar/"

# %%
def get_player_matches(player_id,year,month):
    month_string = str(year)+"-"+str(month).zfill(2)
    history_url="https://gamersclub.com.br/api/box/historyFilterDate/"+str(player_id)+"/"+month_string
    r = requests.get(history_url, cookies=cookies)
    gc_history_data=r.json()
    
    total_matches=gc_history_data["matches"]["matches"]
    matches={}
    if total_matches > 0:
        matches_list=gc_history_data["monthMatches"]
        for match in matches_list:
                matches[match["id"]]=match
                matches[match["id"]]["partipating_players"]=1

        page_count=0
        while len(matches)<total_matches:
            page_count+=1
            history_page_url="https://gamersclub.com.br/api/box/historyMatchesPage/" \
                +str(player_id)+"/"+month_string+"/"+str(page_count)
            r = requests.get(history_page_url, cookies=cookies)

            for match in r.json()["monthMatches"]:
                if not (match["id"] in matches):
                    matches[match["id"]]=match
                    matches[match["id"]]["partipating_players"]=1

    return matches

# %%
matches_dicts=[]
for player_id in player_list:
    
    matches_dicts.append(get_player_matches(player_id,year,month))

    
merged_dict={}
for d in matches_dicts:
    for k,v in d.items():
        if k in merged_dict:
            merged_dict[k]["partipating_players"]+=1
        else:
            merged_dict[k]=v
        

merged_dict
# Out:
# {11039578: {'id': 11039578,
#   'teamNameA': 'milukito',
#   'scoreA': 7,
#   'teamNameB': 'C4 Base',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 1565,
#   'ratingDiff': 9,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11075527: {'id': 11075527,
#   'teamNameA': 'C4 Base',
#   'scoreA': 19,
#   'teamNameB': 'z1pra',
#   'scoreB': 17,
#   'win': 1,
#   'ratingPlayer': 1578,
#   'ratingDiff': 13,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11076977: {'id': 11076977,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'C4 Base',
#   'scoreB': 13,
#   'win': 0,
#   'ratingPlayer': 1562,
#   'ratingDiff': -16,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 6},
#  11078443: {'id': 11078443,
#   'teamNameA': 'AlexZ',
#   'scoreA': 25,
#   'teamNameB': 'C4 Base',
#   'scoreB': 23,
#   'win': 0,
#   'ratingPlayer': 1542,
#   'ratingDiff': -20,
#   'map': 'de_vertigo',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11232684: {'id': 11232684,
#   'teamNameA': 'C4 Base',
#   'scoreA': 9,
#   'teamNameB': 'LoOpEdd',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1527,
#   'ratingDiff': -15,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11233584: {'id': 11233584,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'Scarface',
#   'scoreB': 6,
#   'win': 1,
#   'ratingPlayer': 1537,
#   'ratingDiff': 10,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11234533: {'id': 11234533,
#   'teamNameA': 'C4 Base',
#   'scoreA': 9,
#   'teamNameB': 'Lzn',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1525,
#   'ratingDiff': -12,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11263994: {'id': 11263994,
#   'teamNameA': 'C4 Base',
#   'scoreA': 13,
#   'teamNameB': 'SloWnnn',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1508,
#   'ratingDiff': -17,
#   'map': 'de_nuke',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11024890: {'id': 11024890,
#   'teamNameA': 'BladeMaster',
#   'scoreA': 10,
#   'teamNameB': 'C4 Base',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2041,
#   'ratingDiff': 14,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11034269: {'id': 11034269,
#   'teamNameA': 'C4 Base',
#   'scoreA': 10,
#   'teamNameB': 'Mateus-',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2022,
#   'ratingDiff': -19,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11035157: {'id': 11035157,
#   'teamNameA': 'KretJayZ',
#   'scoreA': 16,
#   'teamNameB': 'C4 Base',
#   'scoreB': 8,
#   'win': 0,
#   'ratingPlayer': 2012,
#   'ratingDiff': -10,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11050393: {'id': 11050393,
#   'teamNameA': 'movimentação de bot',
#   'scoreA': 16,
#   'teamNameB': 'Tody',
#   'scoreB': 12,
#   'win': 0,
#   'ratingPlayer': 2014,
#   'ratingDiff': -10,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 4},
#  11051561: {'id': 11051561,
#   'teamNameA': 'C4 Base',
#   'scoreA': 12,
#   'teamNameB': 'KeimT',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2007,
#   'ratingDiff': -7,
#   'map': 'de_vertigo',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11052595: {'id': 11052595,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'MagonzinN',
#   'scoreB': 10,
#   'win': 1,
#   'ratingPlayer': 2024,
#   'ratingDiff': 17,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11063804: {'id': 11063804,
#   'teamNameA': 'C4 Base',
#   'scoreA': 19,
#   'teamNameB': 'x9 | small[r]',
#   'scoreB': 22,
#   'win': 0,
#   'ratingPlayer': 2010,
#   'ratingDiff': -14,
#   'map': 'de_vertigo',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11080185: {'id': 11080185,
#   'teamNameA': 'wB|Night',
#   'scoreA': 16,
#   'teamNameB': 'C4 Base',
#   'scoreB': 3,
#   'win': 0,
#   'ratingPlayer': 2002,
#   'ratingDiff': -11,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11080832: {'id': 11080832,
#   'teamNameA': 'C4 Base',
#   'scoreA': 14,
#   'teamNameB': 'SkyyGLK',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1994,
#   'ratingDiff': -8,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11168028: {'id': 11168028,
#   'teamNameA': 'MrS',
#   'scoreA': 16,
#   'teamNameB': 'PEDREIRO SUADO.',
#   'scoreB': 12,
#   'win': 1,
#   'ratingPlayer': 2011,
#   'ratingDiff': 17,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 4},
#  11169280: {'id': 11169280,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'betinho o sólido',
#   'scoreB': 10,
#   'win': 1,
#   'ratingPlayer': 2023,
#   'ratingDiff': 12,
#   'map': 'de_cbble_classic',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11183772: {'id': 11183772,
#   'teamNameA': 'waakai',
#   'scoreA': 10,
#   'teamNameB': 'C4 Base',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2035,
#   'ratingDiff': 12,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 6},
#  11184900: {'id': 11184900,
#   'teamNameA': 'waakai',
#   'scoreA': 2,
#   'teamNameB': 'C4 Base',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2045,
#   'ratingDiff': 10,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 6},
#  11196312: {'id': 11196312,
#   'teamNameA': 'C4 Base',
#   'scoreA': 13,
#   'teamNameB': 'AMBiTiONZ AZ A RiDAH',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2029,
#   'ratingDiff': -16,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11197659: {'id': 11197659,
#   'teamNameA': 'C4 Base',
#   'scoreA': 14,
#   'teamNameB': 'nk11',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2013,
#   'ratingDiff': -16,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11210149: {'id': 11210149,
#   'teamNameA': 'aln^',
#   'scoreA': 16,
#   'teamNameB': 'MrS',
#   'scoreB': 10,
#   'win': 0,
#   'ratingPlayer': 2006,
#   'ratingDiff': -7,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 3},
#  11222499: {'id': 11222499,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'BastíN',
#   'scoreB': 19,
#   'win': 0,
#   'ratingPlayer': 1997,
#   'ratingDiff': -9,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11224363: {'id': 11224363,
#   'teamNameA': 'C4 Base',
#   'scoreA': 10,
#   'teamNameB': 'K1bao',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1988,
#   'ratingDiff': -9,
#   'map': 'de_vertigo',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11236324: {'id': 11236324,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'Mathmonster',
#   'scoreB': 8,
#   'win': 1,
#   'ratingPlayer': 1998,
#   'ratingDiff': 15,
#   'map': 'de_vertigo',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11247662: {'id': 11247662,
#   'teamNameA': 'MrS',
#   'scoreA': 17,
#   'teamNameB': 'waakai',
#   'scoreB': 19,
#   'win': 0,
#   'ratingPlayer': 1986,
#   'ratingDiff': -12,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11259942: {'id': 11259942,
#   'teamNameA': 'C4 Base',
#   'scoreA': 11,
#   'teamNameB': 'tLN-',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1975,
#   'ratingDiff': -11,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11260835: {'id': 11260835,
#   'teamNameA': 'C4 Base',
#   'scoreA': 3,
#   'teamNameB': 'Chinote_',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1967,
#   'ratingDiff': -8,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11261675: {'id': 11261675,
#   'teamNameA': 'vnzN1v5',
#   'scoreA': 16,
#   'teamNameB': 'C4 Base',
#   'scoreB': 4,
#   'win': 0,
#   'ratingPlayer': 1955,
#   'ratingDiff': -12,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11262596: {'id': 11262596,
#   'teamNameA': 'C4 Base',
#   'scoreA': 11,
#   'teamNameB': 'fmzx',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1945,
#   'ratingDiff': -10,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11273117: {'id': 11273117,
#   'teamNameA': 'MrS',
#   'scoreA': 16,
#   'teamNameB': 'machT',
#   'scoreB': 3,
#   'win': 1,
#   'ratingPlayer': 1963,
#   'ratingDiff': 18,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 4},
#  11273622: {'id': 11273622,
#   'teamNameA': '2ceps',
#   'scoreA': 19,
#   'teamNameB': 'C4 Base',
#   'scoreB': 15,
#   'win': 0,
#   'ratingPlayer': 1948,
#   'ratingDiff': -15,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11301852: {'id': 11301852,
#   'teamNameA': 'Tnk',
#   'scoreA': 16,
#   'teamNameB': 'ORIGINAL',
#   'scoreB': 14,
#   'win': 1,
#   'ratingPlayer': 1964,
#   'ratingDiff': 16,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 4},
#  11303380: {'id': 11303380,
#   'teamNameA': 'dl-',
#   'scoreA': 16,
#   'teamNameB': 'Tnk',
#   'scoreB': 11,
#   'win': 0,
#   'ratingPlayer': 1954,
#   'ratingDiff': -10,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 4},
#  11310533: {'id': 11310533,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'Siri',
#   'scoreB': 7,
#   'win': 1,
#   'ratingPlayer': 1967,
#   'ratingDiff': 13,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11311158: {'id': 11311158,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'fogogamer',
#   'scoreB': 10,
#   'win': 1,
#   'ratingPlayer': 1978,
#   'ratingDiff': 11,
#   'map': 'de_vertigo',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11164857: {'id': 11164857,
#   'teamNameA': 'C4 Base',
#   'scoreA': 19,
#   'teamNameB': 'aftz',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 1640,
#   'ratingDiff': 12,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11165808: {'id': 11165808,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'zApTZIKA',
#   'scoreB': 14,
#   'win': 1,
#   'ratingPlayer': 1650,
#   'ratingDiff': 10,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11268932: {'id': 11268932,
#   'teamNameA': 'Facada',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 13,
#   'win': 0,
#   'ratingPlayer': 1639,
#   'ratingDiff': -11,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 3},
#  11026428: {'id': 11026428,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'Gui75',
#   'scoreB': 13,
#   'win': 1,
#   'ratingPlayer': 1900,
#   'ratingDiff': 12,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11185649: {'id': 11185649,
#   'teamNameA': 'waakai',
#   'scoreA': 10,
#   'teamNameB': 'C4 Base',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 1889,
#   'ratingDiff': 11,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 6},
#  11289049: {'id': 11289049,
#   'teamNameA': 'C4 Base',
#   'scoreA': 16,
#   'teamNameB': 'Gonpontes',
#   'scoreB': 9,
#   'win': 1,
#   'ratingPlayer': 1751,
#   'ratingDiff': 16,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11290046: {'id': 11290046,
#   'teamNameA': 'C4 Base',
#   'scoreA': 9,
#   'teamNameB': 'Ticorila',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1744,
#   'ratingDiff': -7,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 5},
#  11152648: {'id': 11152648,
#   'teamNameA': 'Hulkão | fb.gg/hulkaomp',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 12,
#   'win': 0,
#   'ratingPlayer': 2029,
#   'ratingDiff': -13,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 3},
#  11221316: {'id': 11221316,
#   'teamNameA': 'waakai',
#   'scoreA': 8,
#   'teamNameB': 'O grill',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2018,
#   'ratingDiff': -10,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 2},
#  11234402: {'id': 11234402,
#   'teamNameA': '.stv',
#   'scoreA': 12,
#   'teamNameB': 'O grill',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2021,
#   'ratingDiff': 19,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11270638: {'id': 11270638,
#   'teamNameA': 'waakai',
#   'scoreA': 9,
#   'teamNameB': 'Mzinn   ;FPS1',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 1976,
#   'ratingDiff': -9,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 2},
#  11027524: {'id': 11027524,
#   'teamNameA': 'Teddy',
#   'scoreA': 13,
#   'teamNameB': 'O grill',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2861,
#   'ratingDiff': 13,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11037694: {'id': 11037694,
#   'teamNameA': 'Guri',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 5,
#   'win': 0,
#   'ratingPlayer': 2851,
#   'ratingDiff': -10,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11038520: {'id': 11038520,
#   'teamNameA': 'O grill',
#   'scoreA': 13,
#   'teamNameB': 'xX_oBsCuRe_Xx',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2838,
#   'ratingDiff': -13,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11048745: {'id': 11048745,
#   'teamNameA': 'Preedad0r',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 7,
#   'win': 0,
#   'ratingPlayer': 2831,
#   'ratingDiff': -7,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11049470: {'id': 11049470,
#   'teamNameA': 'pdr | NTC',
#   'scoreA': 14,
#   'teamNameB': 'O grill',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2848,
#   'ratingDiff': 17,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11052125: {'id': 11052125,
#   'teamNameA': 'Kill Bino',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 5,
#   'win': 0,
#   'ratingPlayer': 2839,
#   'ratingDiff': -9,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11053061: {'id': 11053061,
#   'teamNameA': 'Claudinha',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 6,
#   'win': 0,
#   'ratingPlayer': 2828,
#   'ratingDiff': -11,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11054072: {'id': 11054072,
#   'teamNameA': 'MOTTARADO',
#   'scoreA': 9,
#   'teamNameB': 'waakai',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2845,
#   'ratingDiff': 17,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11064192: {'id': 11064192,
#   'teamNameA': 'betoguinha',
#   'scoreA': 19,
#   'teamNameB': 'waakai',
#   'scoreB': 17,
#   'win': 0,
#   'ratingPlayer': 2837,
#   'ratingDiff': -8,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11066048: {'id': 11066048,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'NST Ecxtaz',
#   'scoreB': 6,
#   'win': 1,
#   'ratingPlayer': 2851,
#   'ratingDiff': 14,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11078563: {'id': 11078563,
#   'teamNameA': 'twitch.tv/hypnosfps',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 11,
#   'win': 0,
#   'ratingPlayer': 2860,
#   'ratingDiff': -4,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11079786: {'id': 11079786,
#   'teamNameA': 'Specian',
#   'scoreA': 9,
#   'teamNameB': 'O grill',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2880,
#   'ratingDiff': 20,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11080853: {'id': 11080853,
#   'teamNameA': 'ricaums',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 6,
#   'win': 0,
#   'ratingPlayer': 2874,
#   'ratingDiff': -6,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11092010: {'id': 11092010,
#   'teamNameA': 'waakai',
#   'scoreA': 17,
#   'teamNameB': 'FELTEN',
#   'scoreB': 19,
#   'win': 0,
#   'ratingPlayer': 2864,
#   'ratingDiff': -10,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11093236: {'id': 11093236,
#   'teamNameA': 'LucasBS',
#   'scoreA': 13,
#   'teamNameB': 'waakai',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2882,
#   'ratingDiff': 18,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11100075: {'id': 11100075,
#   'teamNameA': 'O grill',
#   'scoreA': 16,
#   'teamNameB': 'fepe',
#   'scoreB': 8,
#   'win': 1,
#   'ratingPlayer': 2898,
#   'ratingDiff': 16,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11100855: {'id': 11100855,
#   'teamNameA': 'darkpsy',
#   'scoreA': 19,
#   'teamNameB': 'O grill',
#   'scoreB': 15,
#   'win': 0,
#   'ratingPlayer': 2889,
#   'ratingDiff': -9,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11101916: {'id': 11101916,
#   'teamNameA': 'waakai',
#   'scoreA': 5,
#   'teamNameB': 'Lee1',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2882,
#   'ratingDiff': -7,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11106398: {'id': 11106398,
#   'teamNameA': 'MAMACO',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 8,
#   'win': 0,
#   'ratingPlayer': 2874,
#   'ratingDiff': -8,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11107288: {'id': 11107288,
#   'teamNameA': 'waakai',
#   'scoreA': 6,
#   'teamNameB': 'Malandro.*',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2866,
#   'ratingDiff': -8,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11108096: {'id': 11108096,
#   'teamNameA': 'ISA - twitch.tv/isasudati',
#   'scoreA': 12,
#   'teamNameB': 'waakai',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2887,
#   'ratingDiff': 21,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11108933: {'id': 11108933,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': "rvL'",
#   'scoreB': 14,
#   'win': 1,
#   'ratingPlayer': 2911,
#   'ratingDiff': 24,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11115376: {'id': 11115376,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': '[FREAK]Raffaaa',
#   'scoreB': 10,
#   'win': 1,
#   'ratingPlayer': 2924,
#   'ratingDiff': 13,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11116249: {'id': 11116249,
#   'teamNameA': 'waakai',
#   'scoreA': 11,
#   'teamNameB': '2002',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2907,
#   'ratingDiff': -17,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11119025: {'id': 11119025,
#   'teamNameA': 'necr0000',
#   'scoreA': 4,
#   'teamNameB': 'waakai',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2922,
#   'ratingDiff': 15,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11120031: {'id': 11120031,
#   'teamNameA': 'BIB1PEEK;)',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 13,
#   'win': 0,
#   'ratingPlayer': 2914,
#   'ratingDiff': -8,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11128181: {'id': 11128181,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'gsn',
#   'scoreB': 11,
#   'win': 1,
#   'ratingPlayer': 2926,
#   'ratingDiff': 12,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11131273: {'id': 11131273,
#   'teamNameA': 'thiagueira',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 8,
#   'win': 0,
#   'ratingPlayer': 2916,
#   'ratingDiff': -10,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11132720: {'id': 11132720,
#   'teamNameA': 'waakai',
#   'scoreA': 13,
#   'teamNameB': 'k.v.',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2907,
#   'ratingDiff': -9,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11133912: {'id': 11133912,
#   'teamNameA': 'waakai',
#   'scoreA': 11,
#   'teamNameB': 'EL PATITO',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2898,
#   'ratingDiff': -9,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11143633: {'id': 11143633,
#   'teamNameA': 'Zonhum',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 11,
#   'win': 0,
#   'ratingPlayer': 2882,
#   'ratingDiff': -16,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11145324: {'id': 11145324,
#   'teamNameA': '177',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 6,
#   'win': 0,
#   'ratingPlayer': 2871,
#   'ratingDiff': -11,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11156677: {'id': 11156677,
#   'teamNameA': 'daniel_hod',
#   'scoreA': 3,
#   'teamNameB': 'Jun',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2891,
#   'ratingDiff': 26,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11158021: {'id': 11158021,
#   'teamNameA': 'Ree66',
#   'scoreA': 19,
#   'teamNameB': 'waakai',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2883,
#   'ratingDiff': -8,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11159324: {'id': 11159324,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'O.C',
#   'scoreB': 8,
#   'win': 1,
#   'ratingPlayer': 2898,
#   'ratingDiff': 15,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11170613: {'id': 11170613,
#   'teamNameA': 'WNB',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 11,
#   'win': 0,
#   'ratingPlayer': 2915,
#   'ratingDiff': -17,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11180982: {'id': 11180982,
#   'teamNameA': 'waakai',
#   'scoreA': 22,
#   'teamNameB': 'Drummond',
#   'scoreB': 20,
#   'win': 1,
#   'ratingPlayer': 2941,
#   'ratingDiff': 26,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11181882: {'id': 11181882,
#   'teamNameA': 'waakai',
#   'scoreA': 11,
#   'teamNameB': 'falc',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2932,
#   'ratingDiff': -9,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11182720: {'id': 11182720,
#   'teamNameA': 'waakai',
#   'scoreA': 19,
#   'teamNameB': 'na1ne',
#   'scoreB': 15,
#   'win': 1,
#   'ratingPlayer': 2949,
#   'ratingDiff': 17,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11186645: {'id': 11186645,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'Myrhoo',
#   'scoreB': 11,
#   'win': 1,
#   'ratingPlayer': 2938,
#   'ratingDiff': 16,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11198779: {'id': 11198779,
#   'teamNameA': 'O grill',
#   'scoreA': 5,
#   'teamNameB': 'mAth',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2933,
#   'ratingDiff': -5,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11199562: {'id': 11199562,
#   'teamNameA': 'O grill',
#   'scoreA': 6,
#   'teamNameB': 'dudap',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2926,
#   'ratingDiff': -7,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11207995: {'id': 11207995,
#   'teamNameA': 'www.twitch.tv/b0igod',
#   'scoreA': 11,
#   'teamNameB': 'O grill',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2943,
#   'ratingDiff': 17,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11209991: {'id': 11209991,
#   'teamNameA': 'thigoncalves',
#   'scoreA': 19,
#   'teamNameB': 'O grill',
#   'scoreB': 17,
#   'win': 0,
#   'ratingPlayer': 2936,
#   'ratingDiff': -7,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11211852: {'id': 11211852,
#   'teamNameA': 'thigoncalves',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 9,
#   'win': 0,
#   'ratingPlayer': 2928,
#   'ratingDiff': -8,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11223390: {'id': 11223390,
#   'teamNameA': 'waakai',
#   'scoreA': 25,
#   'teamNameB': 'O grill',
#   'scoreB': 23,
#   'win': 1,
#   'ratingPlayer': 2930,
#   'ratingDiff': 18,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11225644: {'id': 11225644,
#   'teamNameA': 'O grill',
#   'scoreA': 16,
#   'teamNameB': 'kev02k',
#   'scoreB': 6,
#   'win': 1,
#   'ratingPlayer': 2942,
#   'ratingDiff': 12,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11246016: {'id': 11246016,
#   'teamNameA': 'waakai',
#   'scoreA': 9,
#   'teamNameB': 'Tyrekt',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2933,
#   'ratingDiff': -9,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11249339: {'id': 11249339,
#   'teamNameA': 'waakai',
#   'scoreA': 7,
#   'teamNameB': 'Vegas',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2936,
#   'ratingDiff': -16,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11250375: {'id': 11250375,
#   'teamNameA': 'Professor Da Dinamarca',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 19,
#   'win': 1,
#   'ratingPlayer': 2951,
#   'ratingDiff': 15,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11257941: {'id': 11257941,
#   'teamNameA': 'KLB',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 19,
#   'win': 1,
#   'ratingPlayer': 2968,
#   'ratingDiff': 17,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11258823: {'id': 11258823,
#   'teamNameA': 'waakai',
#   'scoreA': 19,
#   'teamNameB': 'gabas',
#   'scoreB': 15,
#   'win': 1,
#   'ratingPlayer': 2988,
#   'ratingDiff': 20,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11263362: {'id': 11263362,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 9,
#   'win': 1,
#   'ratingPlayer': 3004,
#   'ratingDiff': 16,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11264497: {'id': 11264497,
#   'teamNameA': 'waakai',
#   'scoreA': 4,
#   'teamNameB': 'O grill',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2993,
#   'ratingDiff': -7,
#   'map': 'de_cbble_classic',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11265389: {'id': 11265389,
#   'teamNameA': 'Jun',
#   'scoreA': 22,
#   'teamNameB': 'waakai',
#   'scoreB': 19,
#   'win': 0,
#   'ratingPlayer': 2987,
#   'ratingDiff': -6,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11271771: {'id': 11271771,
#   'teamNameA': 'roduite',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 10,
#   'win': 0,
#   'ratingPlayer': 2960,
#   'ratingDiff': -14,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11272533: {'id': 11272533,
#   'teamNameA': 'waakai',
#   'scoreA': 11,
#   'teamNameB': 'Insane.',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2945,
#   'ratingDiff': -15,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11273286: {'id': 11273286,
#   'teamNameA': 'Time Cogu',
#   'scoreA': 16,
#   'teamNameB': 'kYo',
#   'scoreB': 4,
#   'win': 1,
#   'ratingPlayer': 2959,
#   'ratingDiff': 14,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11279010: {'id': 11279010,
#   'teamNameA': 'Mano Alex',
#   'scoreA': 12,
#   'teamNameB': 'waakai',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2977,
#   'ratingDiff': 18,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11279935: {'id': 11279935,
#   'teamNameA': 'waakai',
#   'scoreA': 8,
#   'teamNameB': 'Sebas',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2971,
#   'ratingDiff': -6,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11282339: {'id': 11282339,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'POKAS',
#   'scoreB': 6,
#   'win': 1,
#   'ratingPlayer': 2994,
#   'ratingDiff': 23,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11283269: {'id': 11283269,
#   'teamNameA': 'waakai',
#   'scoreA': 12,
#   'teamNameB': 'Melle',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2987,
#   'ratingDiff': -7,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11284077: {'id': 11284077,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'Hai',
#   'scoreB': 10,
#   'win': 1,
#   'ratingPlayer': 2999,
#   'ratingDiff': 12,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11284874: {'id': 11284874,
#   'teamNameA': 'waakai',
#   'scoreA': 19,
#   'teamNameB': 'mEndez',
#   'scoreB': 17,
#   'win': 1,
#   'ratingPlayer': 3027,
#   'ratingDiff': 28,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11286063: {'id': 11286063,
#   'teamNameA': 'Jun',
#   'scoreA': 15,
#   'teamNameB': 'pAcHeRiN',
#   'scoreB': 19,
#   'win': 0,
#   'ratingPlayer': 2994,
#   'ratingDiff': -6,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11290414: {'id': 11290414,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'DaNN',
#   'scoreB': 3,
#   'win': 1,
#   'ratingPlayer': 3007,
#   'ratingDiff': 13,
#   'map': 'de_overpass',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11291204: {'id': 11291204,
#   'teamNameA': 'pbl_',
#   'scoreA': 19,
#   'teamNameB': 'O grill',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2991,
#   'ratingDiff': -9,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11297882: {'id': 11297882,
#   'teamNameA': 'LnDR',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 11,
#   'win': 0,
#   'ratingPlayer': 2986,
#   'ratingDiff': -5,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11298847: {'id': 11298847,
#   'teamNameA': 'Sh4dowGOD',
#   'scoreA': 16,
#   'teamNameB': 'waakai',
#   'scoreB': 10,
#   'win': 0,
#   'ratingPlayer': 2978,
#   'ratingDiff': -8,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11300384: {'id': 11300384,
#   'teamNameA': 'dark',
#   'scoreA': 16,
#   'teamNameB': 'O grill',
#   'scoreB': 11,
#   'win': 0,
#   'ratingPlayer': 2966,
#   'ratingDiff': -12,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11302498: {'id': 11302498,
#   'teamNameA': 'O grill',
#   'scoreA': 7,
#   'teamNameB': 'LighT',
#   'scoreB': 8,
#   'win': 0,
#   'ratingPlayer': 2966,
#   'ratingDiff': 0,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11304838: {'id': 11304838,
#   'teamNameA': 'MisterMurilo',
#   'scoreA': 12,
#   'teamNameB': 'waakai',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 2988,
#   'ratingDiff': 22,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11312611: {'id': 11312611,
#   'teamNameA': 'waakai',
#   'scoreA': 16,
#   'teamNameB': 'Belinha',
#   'scoreB': 14,
#   'win': 1,
#   'ratingPlayer': 3002,
#   'ratingDiff': 14,
#   'map': 'de_inferno',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11314113: {'id': 11314113,
#   'teamNameA': 'waakai',
#   'scoreA': 10,
#   'teamNameB': 'DIBRANDO',
#   'scoreB': 16,
#   'win': 0,
#   'ratingPlayer': 2989,
#   'ratingDiff': -11,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11137345: {'id': 11137345,
#   'teamNameA': 'Nabo1xx',
#   'scoreA': 6,
#   'teamNameB': 'tt.tv/PSYYYYXITADO',
#   'scoreB': 16,
#   'win': 1,
#   'ratingPlayer': 1590,
#   'ratingDiff': 18,
#   'map': 'de_dust2',
#   'type': 'lobby',
#   'partipating_players': 1},
#  11180720: {'id': 11180720,
#   'teamNameA': 'SALADA-',
#   'scoreA': 16,
#   'teamNameB': 'Kroma',
#   'scoreB': 11,
#   'win': 0,
#   'ratingPlayer': 1581,
#   'ratingDiff': -15,
#   'map': 'de_train',
#   'type': 'lobby',
#   'partipating_players': 1}}

# %%
def filter_matches_to_download(all_matches):
    filtered_matches={}
    for i, (match_id, match) in enumerate(all_matches.items()):
        reason=""
        if not match["partipating_players"]>=3:
            reason = "It's only "+str(match["partipating_players"])+ " participating players."

        if len(glob2.glob(dest_folder+"*_"+str(match_id)+"_*"))>0:
            reason= "It's been downloaded before."

        if reason=="":
            get_download_url="https://gamersclub.com.br/lobby/demoDownload/"+str(match_id)
            r = requests.get(get_download_url, cookies=cookies)
            response_data = r.json()
            if not response_data["success"]:
                print("Error",i,match,response_data)

            else: 
                filtered_matches[match_id]=match
                filtered_matches[match_id]["replay_url"]=response_data["demo"]
                
        else:        
            print("Removing match",match_id,"-",reason)
    return filtered_matches

# %%
filtered_matches=filter_matches_to_download(merged_dict)
filtered_matches
# Out:
# Removing match 11039578 - It's been downloaded before.
# Removing match 11075527 - It's been downloaded before.
# Removing match 11076977 - It's been downloaded before.
# Removing match 11078443 - It's been downloaded before.
# Removing match 11232684 - It's been downloaded before.
# Removing match 11233584 - It's been downloaded before.
# Removing match 11234533 - It's been downloaded before.
# Removing match 11263994 - It's been downloaded before.
# Removing match 11024890 - It's been downloaded before.
# Removing match 11034269 - It's been downloaded before.
# Removing match 11035157 - It's been downloaded before.
# Removing match 11050393 - It's been downloaded before.
# Removing match 11051561 - It's been downloaded before.
# Removing match 11052595 - It's been downloaded before.
# Removing match 11063804 - It's been downloaded before.
# Removing match 11080185 - It's been downloaded before.
# Removing match 11080832 - It's been downloaded before.
# Removing match 11168028 - It's been downloaded before.
# Removing match 11169280 - It's been downloaded before.
# Removing match 11183772 - It's been downloaded before.
# Removing match 11184900 - It's been downloaded before.
# Removing match 11196312 - It's been downloaded before.
# Removing match 11197659 - It's been downloaded before.
# Removing match 11222499 - It's been downloaded before.
# Removing match 11224363 - It's been downloaded before.
# Removing match 11236324 - It's been downloaded before.
# Removing match 11247662 - It's been downloaded before.
# Removing match 11259942 - It's been downloaded before.
# Removing match 11260835 - It's been downloaded before.
# Removing match 11261675 - It's been downloaded before.
# Removing match 11262596 - It's been downloaded before.
# Removing match 11273117 - It's been downloaded before.
# Removing match 11273622 - It's been downloaded before.
# Removing match 11301852 - It's been downloaded before.
# Removing match 11303380 - It's been downloaded before.
# Removing match 11310533 - It's been downloaded before.
# Removing match 11311158 - It's been downloaded before.
# Removing match 11164857 - It's been downloaded before.
# Removing match 11165808 - It's been downloaded before.
# Removing match 11268932 - It's been downloaded before.
# Removing match 11026428 - It's been downloaded before.
# Removing match 11185649 - It's been downloaded before.
# Removing match 11289049 - It's been downloaded before.
# Removing match 11290046 - It's been downloaded before.
# Removing match 11152648 - It's been downloaded before.
# Removing match 11221316 - It's only 2 participating players.
# Removing match 11234402 - It's only 1 participating players.
# Removing match 11270638 - It's only 2 participating players.
# Removing match 11027524 - It's only 1 participating players.
# Removing match 11037694 - It's only 1 participating players.
# Removing match 11038520 - It's only 1 participating players.
# Removing match 11048745 - It's only 1 participating players.
# Removing match 11049470 - It's only 1 participating players.
# Removing match 11052125 - It's only 1 participating players.
# Removing match 11053061 - It's only 1 participating players.
# Removing match 11054072 - It's only 1 participating players.
# Removing match 11064192 - It's only 1 participating players.
# Removing match 11066048 - It's only 1 participating players.
# Removing match 11078563 - It's only 1 participating players.
# Removing match 11079786 - It's only 1 participating players.
# Removing match 11080853 - It's only 1 participating players.
# Removing match 11092010 - It's only 1 participating players.
# Removing match 11093236 - It's only 1 participating players.
# Removing match 11100075 - It's only 1 participating players.
# Removing match 11100855 - It's only 1 participating players.
# Removing match 11101916 - It's only 1 participating players.
# Removing match 11106398 - It's only 1 participating players.
# Removing match 11107288 - It's only 1 participating players.
# Removing match 11108096 - It's only 1 participating players.
# Removing match 11108933 - It's only 1 participating players.
# Removing match 11115376 - It's only 1 participating players.
# Removing match 11116249 - It's only 1 participating players.
# Removing match 11119025 - It's only 1 participating players.
# Removing match 11120031 - It's only 1 participating players.
# Removing match 11128181 - It's only 1 participating players.
# Removing match 11131273 - It's only 1 participating players.
# Removing match 11132720 - It's only 1 participating players.
# Removing match 11133912 - It's only 1 participating players.
# Removing match 11143633 - It's only 1 participating players.
# Removing match 11145324 - It's only 1 participating players.
# Removing match 11156677 - It's only 1 participating players.
# Removing match 11158021 - It's only 1 participating players.
# Removing match 11159324 - It's only 1 participating players.
# Removing match 11170613 - It's only 1 participating players.
# Removing match 11180982 - It's only 1 participating players.
# Removing match 11181882 - It's only 1 participating players.
# Removing match 11182720 - It's only 1 participating players.
# Removing match 11186645 - It's only 1 participating players.
# Removing match 11198779 - It's only 1 participating players.
# Removing match 11199562 - It's only 1 participating players.
# Removing match 11207995 - It's only 1 participating players.
# Removing match 11209991 - It's only 1 participating players.
# Removing match 11211852 - It's only 1 participating players.
# Removing match 11223390 - It's only 1 participating players.
# Removing match 11225644 - It's only 1 participating players.
# Removing match 11246016 - It's only 1 participating players.
# Removing match 11249339 - It's only 1 participating players.
# Removing match 11250375 - It's only 1 participating players.
# Removing match 11257941 - It's only 1 participating players.
# Removing match 11258823 - It's only 1 participating players.
# Removing match 11263362 - It's only 1 participating players.
# Removing match 11264497 - It's only 1 participating players.
# Removing match 11265389 - It's only 1 participating players.
# Removing match 11271771 - It's only 1 participating players.
# Removing match 11272533 - It's only 1 participating players.
# Removing match 11273286 - It's only 1 participating players.
# Removing match 11279010 - It's only 1 participating players.
# Removing match 11279935 - It's only 1 participating players.
# Removing match 11282339 - It's only 1 participating players.
# Removing match 11283269 - It's only 1 participating players.
# Removing match 11284077 - It's only 1 participating players.
# Removing match 11284874 - It's only 1 participating players.
# Removing match 11286063 - It's only 1 participating players.
# Removing match 11290414 - It's only 1 participating players.
# Removing match 11291204 - It's only 1 participating players.
# Removing match 11297882 - It's only 1 participating players.
# Removing match 11298847 - It's only 1 participating players.
# Removing match 11300384 - It's only 1 participating players.
# Removing match 11302498 - It's only 1 participating players.
# Removing match 11304838 - It's only 1 participating players.
# Removing match 11312611 - It's only 1 participating players.
# Removing match 11314113 - It's only 1 participating players.
# Removing match 11137345 - It's only 1 participating players.
# Removing match 11180720 - It's only 1 participating players.
# {11210149: {'id': 11210149,
#   'teamNameA': 'aln^',
#   'scoreA': 16,
#   'teamNameB': 'MrS',
#   'scoreB': 10,
#   'win': 0,
#   'ratingPlayer': 2006,
#   'ratingDiff': -7,
#   'map': 'de_mirage',
#   'type': 'lobby',
#   'partipating_players': 3,
#   'replay_url': 'https://prod-demo-parser-gc-demos.s3.amazonaws.com/2021-03-15__2204__1__11210149__de_mirage__timemrs__vs__timealn.zip'}}

# %%
len(filtered_matches)
# Out:
# 1

# %%
def download_replays(matches):
    for _,match in matches.items():
        direct_download_url=match["replay_url"]
        match_name=direct_download_url[direct_download_url.rfind("/")+1:-4]
        match_file = Path(dest_folder+match_name+".dem")
        if not match_file.is_file():
            r = requests.get(direct_download_url)
            z = zipfile.ZipFile(io.BytesIO(r.content))
            z.extractall(dest_folder)
        else:
            print(match_name, "was downloaded before.")

# %%
download_replays(filtered_matches)
